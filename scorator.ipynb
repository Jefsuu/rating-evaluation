# %%
import pandas as pd
import requests
from sqlalchemy import create_engine

# %%
CREATE TABLE IF NOT EXISTS rated_reviews (
            id_review int,
            is_positive boolean
        )

# %%
engine = create_engine("postgresql://dev_user:1234@localhost:5432/reviews")
pd.read_sql_query("SELECT max(id) max_id FROM rated_reviews", con=engine)
